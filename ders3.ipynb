# %%
import pandas as pd
import os
import numpy as np

# %%
pokemon = pd.read_csv("C:/Users/sevval/Desktop/pokemon.csv")

# %%
pokemon.shape
# Out:
# (1072, 13)

# %%
pokemon.head(4)
# Out:
#    number           name  type1   type2  total  hp  attack  defense  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49
# 1       2        Ivysaur  Grass  Poison    405  60      62       63
# 2       3       Venusaur  Grass  Poison    525  80      82       83
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123
#
#    sp_attack  sp_defense  speed  generation  legendary
# 0         65          65     45           1      False
# 1         80          80     60           1      False
# 2        100         100     80           1      False
# 3        122         120     80           1      False

# %%
del pokemon["generation"]

# %%
pokemon.head(4)
# Out:
#    number           name  type1   type2  total  hp  attack  defense  \
# 0       1      Bulbasaur  Grass  Poison    318  45      49       49
# 1       2        Ivysaur  Grass  Poison    405  60      62       63
# 2       3       Venusaur  Grass  Poison    525  80      82       83
# 3       3  Mega Venusaur  Grass  Poison    625  80     100      123
#
#    sp_attack  sp_defense  speed  legendary
# 0         65          65     45      False
# 1         80          80     60      False
# 2        100         100     80      False
# 3        122         120     80      False

# %%
pokemon["type2"].describe()
# Out:
# count        574
# unique        18
# top       Flying
# freq         114
# Name: type2, dtype: object

# %%
missing=np.where(pokemon["type2"].isnull()==True)
missing
# Out:
# (array([   5,    6,   11,   12,   13,   14,   16,   17,   28,   30,   34,
#           35,   36,   37,   38,   40,   42,   44,   45,   47,   48,   50,
#           51,   52,   53,   54,   67,   69,   71,   72,   73,   74,   75,
#           76,   77,   78,   79,   80,   81,   82,   83,   84,   86,   87,
#           88,   89,   90,   91,   92,   93,  105,  107,  110,  117,  120,
#          122,  124,  126,  134,  135,  136,  137,  138,  139,  140,  144,
#          145,  147,  148,  149,  150,  151,  155,  156,  157,  158,  159,
#          160,  161,  162,  163,  169,  170,  171,  173,  174,  179,  180,
#          181,  182,  183,  184,  185,  192,  193,  200,  201,  203,  205,
#          206,  207,  208,  209,  210,  211,  212,  213,  214,  215,  216,
#          217,  227,  228,  230,  234,  235,  236,  238,  241,  242,  246,
#          247,  248,  252,  253,  257,  258,  259,  261,  263,  267,  268,
#          276,  277,  278,  283,  284,  285,  293,  294,  295,  296,  297,
#          298,  299,  301,  302,  303,  304,  305,  306,  307,  315,  316,
#          317,  319,  323,  327,  328,  329,  331,  333,  334,  336,  341,
#          354,  356,  357,  358,  362,  363,  364,  365,  366,  368,  369,
#          370,  378,  382,  383,  384,  385,  386,  387,  388,  390,  391,
#          395,  396,  400,  401,  402,  403,  404,  407,  412,  413,  418,
#          426,  427,  428,  429,  430,  431,  432,  433,  434,  436,  437,
#          438,  439,  440,  441,  442,  446,  447,  448,  450,  451,  452,
#          459,  460,  461,  466,  467,  468,  473,  474,  475,  476,  477,
#          478,  480,  483,  484,  489,  491,  492,  493,  494,  495,  498,
#          499,  502,  509,  510,  511,  512,  513,  514,  516,  519,  520,
#          522,  524,  525,  526,  531,  533,  540,  541,  544,  545,  550,
#          551,  552,  559,  561,  562,  563,  566,  567,  570,  574,  582,
#          583,  584,  588,  591,  592,  593,  594,  595,  597,  599,  600,
#          601,  602,  605,  606,  607,  608,  609,  610,  611,  612,  613,
#          614,  615,  616,  617,  618,  619,  620,  621,  622,  626,  627,
#          628,  629,  630,  633,  635,  637,  638,  639,  640,  643,  644,
#          653,  654,  655,  659,  660,  661,  662,  665,  671,  673,  678,
#          679,  680,  681,  682,  683,  684,  685,  686,  687,  688,  689,
#          690,  693,  694,  695,  699,  705,  710,  711,  712,  713,  714,
#          715,  716,  717,  721,  722,  723,  724,  725,  726,  727,  728,
#          731,  732,  733,  738,  743,  753,  754,  769,  770,  772,  773,
#          775,  776,  779,  784,  785,  789,  790,  791,  792,  793,  794,
#          796,  797,  798,  799,  804,  805,  806,  807,  814,  815,  822,
#          826,  827,  828,  840,  841,  844,  857,  858,  860,  861,  866,
#          867,  868,  871,  879,  880,  881,  882,  883,  884,  887,  888,
#          891,  892,  899,  900,  901,  902,  904,  909,  910,  911,  914,
#          921,  928,  929,  935,  939,  945,  949,  950,  951,  952,  953,
#          954,  955,  956,  957,  958,  959,  960,  961,  962,  963,  964,
#          965,  966,  967,  968,  971,  975,  976,  977,  978,  979,  980,
#          981,  984,  985,  986,  995,  996,  997,  999, 1000, 1008, 1009,
#         1010, 1011, 1012, 1013, 1021, 1022, 1023, 1026, 1027, 1028, 1029,
#         1030, 1033, 1034, 1035, 1040, 1041, 1042, 1052, 1054, 1058, 1065,
#         1066, 1067, 1068], dtype=int64),)

# %%
len(missing[0])
# Out:
# 498

# %% [markdown]
# # seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset("flights")

# %%
data=data.pivot("month","year","passengers")

# %%
sns.heatmap(data=data,annot=True,fmt="d",cmap="YlGnBu")
plt.show()

# %%
data.info
# Out:
# <bound method DataFrame.info of year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432>

# %%
data=sns.load_dataset("flights")
#line plot
sns.lineplot(data=data,x="year",y="passengers")
plt.show()

# %%
data=sns.load_dataset("iris")
sns.swarmplot(x="species",y="petal_length",data=data)
plt.show()
# Out:
# C:\Users\sevval\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset("tips")
sns.scatterplot(data=data,x="total_bill",y="tip")
plt.show()

# %%
iris=sns.load_dataset("iris")
g=sns.clustermap(iris.drop("species",axis=1),cmap="coolwarm",standard_scale=1)
plt.show()

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>
